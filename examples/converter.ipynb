# %% [markdown]
# # Converter

# %% [markdown]
# ## IGraph

# %% [markdown]
# ## NetWorkX

# %% [markdown]
# ## MetExplore
#
# First, we create a Cobra model for which we want to create files to be able to read them with MetExploreViz.First, we create a Cobra model for which we want to create files to be able to read them with MetExploreViz.

# %%
import cobra
from cobra.io import read_sbml_model
from importlib_resources import files, as_file

textbook_raw = files(cobra.data).joinpath("textbook.xml.gz")
with as_file(textbook_raw) as textbookXML:
    textbook = read_sbml_model(str(textbookXML))
    
textbook = read_sbml_model("/home/jan/Downloads/PlantCoreMetabolism_v2_0_0.xml")

# %% [markdown]
# For the representation of the model itself, we can either create the JSON string or directly create a file containing it. In the following, first the string is created as an example and then the file.For the representation of the model itself, we can either create the JSON string or directly create a file containing it. In the following, first the string is created as an example and then the file.

# %%
import pprint
from model_duplication.visualization import converter

JSON_string = converter.cobra2metexplore(textbook)
print(JSON_string)
# Out:
# {
#     "nodes": [
#         {
#             "name": "UREA",
#             "id": "UREA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "VAL",
#             "id": "VAL_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sVAL[b]",
#             "id": "sVAL_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLYCEROL-3P",
#             "id": "GLYCEROL_3P_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "VAL",
#             "id": "VAL_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "dCDP[p]",
#             "id": "aDCDP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "N-5-PHOSPHORIBOSYL-ANTHRANILATE",
#             "id": "N_5_PHOSPHORIBOSYL_ANTHRANILATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "UREA",
#             "id": "UREA_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ACETOACETATE",
#             "id": "ACETOACETATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P",
#             "id": "CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sSUCROSE[b]",
#             "id": "sSUCROSE_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLN",
#             "id": "GLN_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DELTA3-ISOPENTENYL-PP[p]",
#             "id": "aDELTA3_ISOPENTENYL_PP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3_oxo_hexanoyl_ACPs[p]",
#             "id": "3_oxo_hexanoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "XYLULOSE-5-PHOSPHATE",
#             "id": "XYLULOSE_5_PHOSPHATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLN",
#             "id": "GLN_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLN",
#             "id": "GLN_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FORMATE",
#             "id": "FORMATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FORMATE",
#             "id": "FORMATE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "pGLN[b]",
#             "id": "pGLN_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "XYLULOSE-5-PHOSPHATE",
#             "id": "XYLULOSE_5_PHOSPHATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FORMATE",
#             "id": "FORMATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NADPH",
#             "id": "NADPH_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DADP",
#             "id": "DADP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "pVAL[b]",
#             "id": "pVAL_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "INDOLE-3-GLYCEROL-P",
#             "id": "INDOLE_3_GLYCEROL_P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-1083",
#             "id": "CPD_1083_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLN",
#             "id": "GLN_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DELTA3-ISOPENTENYL-PP[c]",
#             "id": "aDELTA3_ISOPENTENYL_PP_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DEHYDROQUINATE",
#             "id": "DEHYDROQUINATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "pPHE[b]",
#             "id": "pPHE_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SHIKIMATE-5P",
#             "id": "SHIKIMATE_5P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-ASPARTATE",
#             "id": "L_ASPARTATE_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PLASTOQUINOL_1[p]",
#             "id": "PLASTOQUINOL_1_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3_Oxo_octanoyl_ACPs[p]",
#             "id": "3_Oxo_octanoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ISOBUTYRYL-COA",
#             "id": "ISOBUTYRYL_COA_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ALA_tRNAs[c]",
#             "id": "ALA_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MET_tRNAs[c]",
#             "id": "MET_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHE",
#             "id": "PHE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NADPH",
#             "id": "NADPH_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-11281",
#             "id": "bCPD_11281_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "VAL",
#             "id": "VAL_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NADPH",
#             "id": "NADPH_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "UDP_GLUCOSE[c]",
#             "id": "UDP_GLUCOSE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "VAL",
#             "id": "VAL_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHE",
#             "id": "PHE_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-650",
#             "id": "CPD_650_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HYDROXY-METHYL-BUTENYL-DIP",
#             "id": "HYDROXY_METHYL_BUTENYL_DIP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NADPH",
#             "id": "NADPH_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLYCEROL-3P",
#             "id": "GLYCEROL_3P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLYCEROL-3P",
#             "id": "GLYCEROL_3P_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MYO-INOSITOL",
#             "id": "MYO_INOSITOL_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROPIONYL-COA",
#             "id": "PROPIONYL_COA_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "TYR",
#             "id": "TYR_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sCIT[b]",
#             "id": "sCIT_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "STARCH[p]",
#             "id": "STARCH_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-CITRULLINE",
#             "id": "L_CITRULLINE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ISOBUTYRYL-COA",
#             "id": "ISOBUTYRYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROPIONYL-COA",
#             "id": "PROPIONYL_COA_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-CITRULLINE",
#             "id": "L_CITRULLINE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "TYR",
#             "id": "TYR_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ISOBUTYRYL-COA",
#             "id": "ISOBUTYRYL_COA_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHE",
#             "id": "PHE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sPHE[b]",
#             "id": "sPHE_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Charged_GLT_tRNAs[c]",
#             "id": "Charged_GLT_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROPIONYL-COA",
#             "id": "PROPIONYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLC-6-P",
#             "id": "GLC_6_P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-P-SERINE",
#             "id": "3_P_SERINE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-CITRULLINE",
#             "id": "L_CITRULLINE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CHORISMATE",
#             "id": "CHORISMATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-1-PHOSPHATIDYL-ETHANOLAMINE[r]",
#             "id": "L_1_PHOSPHATIDYL_ETHANOLAMINE_r",
#             "compartment": "r",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "LYS_tRNAs[c]",
#             "id": "LYS_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "TYR",
#             "id": "TYR_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sTYR[b]",
#             "id": "sTYR_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "pTYR[b]",
#             "id": "pTYR_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SUC-COA",
#             "id": "SUC_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DPG",
#             "id": "DPG_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "N-ALPHA-ACETYLORNITHINE",
#             "id": "N_ALPHA_ACETYLORNITHINE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aADP[c]",
#             "id": "aADP_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aADP[m]",
#             "id": "aADP_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aADP[p]",
#             "id": "aADP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-3-HYDROXY-BUTYRYL-COA",
#             "id": "2_METHYL_3_HYDROXY_BUTYRYL_COA_c",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DPG",
#             "id": "DPG_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-3-HYDROXY-BUTYRYL-COA",
#             "id": "2_METHYL_3_HYDROXY_BUTYRYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLC-6-P",
#             "id": "GLC_6_P_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-3-HYDROXY-BUTYRYL-COA",
#             "id": "2_METHYL_3_HYDROXY_BUTYRYL_COA_x",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SUCROSE-6P",
#             "id": "SUCROSE_6P_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE",
#             "id": "PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Charged_GLN_tRNAs[c]",
#             "id": "Charged_GLN_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SO3",
#             "id": "SO3_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-1777",
#             "id": "CPD_1777_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "AMP",
#             "id": "AMP_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHOSPHATIDYL-CHOLINE[r]",
#             "id": "PHOSPHATIDYL_CHOLINE_r",
#             "compartment": "r",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PALMITATE",
#             "id": "PALMITATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SO3",
#             "id": "SO3_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FRUCTOSE-16-DIPHOSPHATE",
#             "id": "FRUCTOSE_16_DIPHOSPHATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-ACETO-ACETYL-COA",
#             "id": "2_METHYL_ACETO_ACETYL_COA_c",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sFUM[b]",
#             "id": "sFUM_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PALMITATE",
#             "id": "PALMITATE_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-ACETO-ACETYL-COA",
#             "id": "2_METHYL_ACETO_ACETYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PALMITATE",
#             "id": "PALMITATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sGABA[b]",
#             "id": "sGABA_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2-METHYL-ACETO-ACETYL-COA",
#             "id": "2_METHYL_ACETO_ACETYL_COA_x",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Trans_D2_decenoyl_ACPs[p]",
#             "id": "Trans_D2_decenoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FRUCTOSE-16-DIPHOSPHATE",
#             "id": "FRUCTOSE_16_DIPHOSPHATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-7014",
#             "id": "CPD_7014_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MALONATE-S-ALD",
#             "id": "MALONATE_S_ALD_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aPRPP[p]",
#             "id": "aPRPP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CDP[m]",
#             "id": "aCDP_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CDP[p]",
#             "id": "aCDP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CONIFERYL-ALCOHOL",
#             "id": "CONIFERYL_ALCOHOL_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "AMP",
#             "id": "AMP_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "dADP[p]",
#             "id": "aDADP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "AMP",
#             "id": "AMP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "AMP",
#             "id": "AMP_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Charged_PHE_tRNAs[c]",
#             "id": "Charged_PHE_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-ALPHA-ALANINE",
#             "id": "L_ALPHA_ALANINE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "R_3_Hydroxypalmitoyl_ACPs[p]",
#             "id": "R_3_Hydroxypalmitoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "THF",
#             "id": "THF_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HOMO-CYS",
#             "id": "HOMO_CYS_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-14927[c]",
#             "id": "CPD_14927_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Tetradec_2_enoyl_ACPs[p]",
#             "id": "Tetradec_2_enoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-14927[x]",
#             "id": "CPD_14927_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "THF",
#             "id": "THF_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-ALPHA-ALANINE",
#             "id": "L_ALPHA_ALANINE_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-ALPHA-ALANINE",
#             "id": "L_ALPHA_ALANINE_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CARBAMYUL-L-ASPARTATE",
#             "id": "CARBAMYUL_L_ASPARTATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "THF",
#             "id": "THF_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-14927[p]",
#             "id": "CPD_14927_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-ALPHA-ALANINE",
#             "id": "L_ALPHA_ALANINE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Cytochromes_C_Oxidized[mi]",
#             "id": "Cytochromes_C_Oxidized_mi",
#             "compartment": "mi",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Cytochromes_C_Oxidized[mc]",
#             "id": "Cytochromes_C_Oxidized_mc",
#             "compartment": "mc",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Cellulose[b]",
#             "id": "Cellulose_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "5-10-METHENYL-THF",
#             "id": "5_10_METHENYL_THF_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLC",
#             "id": "GLC_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-DELTA1-PYRROLINE-5-CARBOXYLATE_c",
#             "id": "L_DELTA1_PYRROLINE_5_CARBOXYLATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "METHACRYL-COA[m]",
#             "id": "METHACRYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HOMO-CYS",
#             "id": "HOMO_CYS_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLT_tRNAs[c]",
#             "id": "GLT_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "O-PHOSPHO-L-HOMOSERINE",
#             "id": "O_PHOSPHO_L_HOMOSERINE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ACETYL-GLU",
#             "id": "ACETYL_GLU_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aSO3[m]",
#             "id": "aSO3_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-11281",
#             "id": "CPD_11281_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "APS",
#             "id": "APS_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-DELTA-PYRROLINE_5-CARBOXYLATE",
#             "id": "L_DELTA1_PYRROLINE_5_CARBOXYLATE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-7016",
#             "id": "CPD_7016_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aPi[x]",
#             "id": "aPi_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLN_tRNAs[c]",
#             "id": "GLN_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aSO3[p]",
#             "id": "aSO3_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CHLOROPHYLL-B",
#             "id": "CHLOROPHYLL_B_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ANTHRANILATE",
#             "id": "ANTHRANILATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ADP",
#             "id": "ADP_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HISTIDINAL",
#             "id": "HISTIDINAL_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SER",
#             "id": "SER_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ADP-D-GLUCOSE",
#             "id": "ADP_D_GLUCOSE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SER",
#             "id": "SER_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GERANYLGERANYL-PP[p]",
#             "id": "aGERANYLGERANYL_PP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-5441",
#             "id": "CPD_5441_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-DEHYDRO-SHIKIMATE",
#             "id": "3_DEHYDRO_SHIKIMATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SER",
#             "id": "SER_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NITRATE",
#             "id": "NITRATE_e",
#             "compartment": "e",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FeIII[c]",
#             "id": "FeIII_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NITRATE",
#             "id": "NITRATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Oxidized_Plastocyanins[p]",
#             "id": "Oxidized_Plastocyanins_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SER",
#             "id": "SER_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SUCROSE",
#             "id": "SUCROSE_e",
#             "compartment": "e",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "FRUCTAN[v]",
#             "id": "FRUCTAN_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SER",
#             "id": "SER_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GAP",
#             "id": "GAP_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SUCROSE",
#             "id": "SUCROSE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NITRATE",
#             "id": "NITRATE_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE",
#             "id": "PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GAP",
#             "id": "GAP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "SUCROSE",
#             "id": "SUCROSE_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ADP",
#             "id": "ADP_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ADP",
#             "id": "ADP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NAD",
#             "id": "NAD_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NAD",
#             "id": "NAD_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-ENOLPYRUVYL-SHIKIMATE-5P",
#             "id": "3_ENOLPYRUVYL_SHIKIMATE_5P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NAD",
#             "id": "NAD_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aPi[c]",
#             "id": "aPi_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "NAD",
#             "id": "NAD_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "dGTP[p]",
#             "id": "bDGTP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "OXIDIZED-GLUTATHIONE",
#             "id": "OXIDIZED_GLUTATHIONE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "OXIDIZED-GLUTATHIONE",
#             "id": "OXIDIZED_GLUTATHIONE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "P-HYDROXY-PHENYLPYRUVATE",
#             "id": "P_HYDROXY_PHENYLPYRUVATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "4-FUMARYL-ACETOACETATE",
#             "id": "4_FUMARYL_ACETOACETATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "INDOLE",
#             "id": "INDOLE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CMP",
#             "id": "CMP_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "K[b]",
#             "id": "K_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CMP",
#             "id": "CMP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CHLOROPHYLLIDE-A",
#             "id": "CHLOROPHYLLIDE_A_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-11281",
#             "id": "aCPD_11281_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "P-HYDROXY-PHENYLPYRUVATE",
#             "id": "P_HYDROXY_PHENYLPYRUVATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ACYL-SN-GLYCEROL-3P",
#             "id": "ACYL_SN_GLYCEROL_3P_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CDP-ETHANOLAMINE",
#             "id": "CDP_ETHANOLAMINE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "pCYS[b]",
#             "id": "pCYS_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_e",
#             "compartment": "e",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Myristoyl_ACPs[p]",
#             "id": "Myristoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Charged_TYR_tRNAs[c]",
#             "id": "Charged_TYR_tRNAs_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-GLUTAMATE-GAMMA-SEMIALDEHYDE_c",
#             "id": "L_GLUTAMATE_GAMMA_SEMIALDEHYDE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "5-PHOSPHORIBOSYL-N-FORMYLGLYCINEAMIDINE",
#             "id": "5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE",
#             "id": "a5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Plastocyanin_Reduced[p]",
#             "id": "Plastocyanin_Reduced_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "CPD-4211",
#             "id": "CPD_4211_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L_GLUTAMATE_GAMMA_SEMIALDEHYDE[m]",
#             "id": "L_GLUTAMATE_GAMMA_SEMIALDEHYDE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "2_Octenoyl_ACPs[p]",
#             "id": "2_Octenoyl_ACPs_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "WATER",
#             "id": "WATER_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PHYTYL-PYROPHOSPHATE",
#             "id": "PHYTYL_PYROPHOSPHATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "aL-GLUTAMATE-5-P_c",
#             "id": "aL_GLUTAMATE_5_P_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MGII[e]",
#             "id": "MGII_e",
#             "compartment": "e",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "LL-DIAMINOPIMELATE",
#             "id": "LL_DIAMINOPIMELATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MGII[c]",
#             "id": "MGII_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "L-GLUTAMATE-5-P",
#             "id": "L_GLUTAMATE_5_P_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "5-PHOSPHO-RIBOSYL-GLYCINEAMIDE",
#             "id": "5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "Oxidized_ferredoxins[p]",
#             "id": "Oxidized_ferredoxins_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PYRUVATE",
#             "id": "PYRUVATE_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLUTACONYL-COA",
#             "id": "GLUTACONYL_COA_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DIOH_ISOVALERATE[p]",
#             "id": "DIOH_ISOVALERATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ACETALD",
#             "id": "ACETALD_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "ETOH",
#             "id": "ETOH_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DATP",
#             "id": "DATP_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLUTACONYL-COA",
#             "id": "GLUTACONYL_COA_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "sMAL[b]",
#             "id": "sMAL_b",
#             "compartment": "b",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "MGII[v]",
#             "id": "MGII_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "GLUTACONYL-COA",
#             "id": "GLUTACONYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-METHYL-CROTONYL-COA",
#             "id": "3_METHYL_CROTONYL_COA_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "OXIDIZED-GLUTATHIONE",
#             "id": "bOXIDIZED_GLUTATHIONE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROTON",
#             "id": "PROTON_v",
#             "compartment": "v",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HCO3",
#             "id": "HCO3_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "OXIDIZED-GLUTATHIONE",
#             "id": "bOXIDIZED_GLUTATHIONE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-HYDROXY-PROPIONATE",
#             "id": "3_HYDROXY_PROPIONATE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROTON",
#             "id": "PROTON_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROTON",
#             "id": "PROTON_l",
#             "compartment": "l",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "HCO3",
#             "id": "HCO3_c",
#             "compartment": "c",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROTON",
#             "id": "PROTON_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PYRUVATE",
#             "id": "PYRUVATE_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PROTON",
#             "id": "PROTON_i",
#             "compartment": "i",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PYRUVATE",
#             "id": "PYRUVATE_m",
#             "compartment": "m",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "3-HYDROXY-PROPIONATE",
#             "id": "3_HYDROXY_PROPIONATE_x",
#             "compartment": "x",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "PYRUVATE",
#             "id": "PYRUVATE_p",
#             "compartment": "p",
#             "biologicalType": "metabolite",
#             "pathways": []
#         },
#         {
#             "name": "DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE",
#             "id": "DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_p",
# ...
#             "id": "RXN_1104_p -- aVANILLIN_p"
#         },
#         {
#             "source": 1741,
#             "target": 271,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_1104_p -- ACET_p"
#         },
#         {
#             "source": 844,
#             "target": 1742,
#             "interaction": "in",
#             "reversible": true,
#             "id": "VANILLIN_p -- VANILLIN_pc"
#         },
#         {
#             "source": 845,
#             "target": 1742,
#             "interaction": "in",
#             "reversible": true,
#             "id": "aVANILLIN_p -- VANILLIN_pc"
#         },
#         {
#             "source": 236,
#             "target": 1742,
#             "interaction": "in",
#             "reversible": true,
#             "id": "PROTON_p -- VANILLIN_pc"
#         },
#         {
#             "source": 1742,
#             "target": 836,
#             "interaction": "out",
#             "reversible": true,
#             "id": "VANILLIN_pc -- aVANILLIN_c"
#         },
#         {
#             "source": 1742,
#             "target": 835,
#             "interaction": "out",
#             "reversible": true,
#             "id": "VANILLIN_pc -- VANILLIN_c"
#         },
#         {
#             "source": 350,
#             "target": 1743,
#             "interaction": "in",
#             "reversible": false,
#             "id": "ATP_p -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p"
#         },
#         {
#             "source": 272,
#             "target": 1743,
#             "interaction": "in",
#             "reversible": false,
#             "id": "CO_A_p -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p"
#         },
#         {
#             "source": 843,
#             "target": 1743,
#             "interaction": "in",
#             "reversible": false,
#             "id": "FERULIC_ACID_p -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p"
#         },
#         {
#             "source": 644,
#             "target": 1743,
#             "interaction": "in",
#             "reversible": false,
#             "id": "aATP_p -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p"
#         },
#         {
#             "source": 1743,
#             "target": 602,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p -- PPI_p"
#         },
#         {
#             "source": 1743,
#             "target": 649,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p -- bPPI_p"
#         },
#         {
#             "source": 1743,
#             "target": 113,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p -- AMP_p"
#         },
#         {
#             "source": 1743,
#             "target": 847,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_p -- FERULOYL_COA_p"
#         },
#         {
#             "source": 266,
#             "target": 1744,
#             "interaction": "in",
#             "reversible": false,
#             "id": "CO_A_c -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c"
#         },
#         {
#             "source": 354,
#             "target": 1744,
#             "interaction": "in",
#             "reversible": false,
#             "id": "ATP_c -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c"
#         },
#         {
#             "source": 842,
#             "target": 1744,
#             "interaction": "in",
#             "reversible": false,
#             "id": "FERULIC_ACID_c -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c"
#         },
#         {
#             "source": 650,
#             "target": 1744,
#             "interaction": "in",
#             "reversible": false,
#             "id": "aATP_c -- 6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c"
#         },
#         {
#             "source": 1744,
#             "target": 91,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c -- AMP_c"
#         },
#         {
#             "source": 1744,
#             "target": 617,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c -- PPI_c"
#         },
#         {
#             "source": 1744,
#             "target": 846,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c -- FERULOYL_COA_c"
#         },
#         {
#             "source": 1744,
#             "target": 603,
#             "interaction": "out",
#             "reversible": false,
#             "id": "6_PERIOD_2_PERIOD_1_PERIOD_34_RXN_c -- aPPI_c"
#         },
#         {
#             "source": 176,
#             "target": 1745,
#             "interaction": "in",
#             "reversible": false,
#             "id": "NAD_c -- ACETOVANILLONE_SYNTHASE_c"
#         },
#         {
#             "source": 846,
#             "target": 1745,
#             "interaction": "in",
#             "reversible": false,
#             "id": "FERULOYL_COA_c -- ACETOVANILLONE_SYNTHASE_c"
#         },
#         {
#             "source": 199,
#             "target": 1745,
#             "interaction": "in",
#             "reversible": false,
#             "id": "WATER_c -- ACETOVANILLONE_SYNTHASE_c"
#         },
#         {
#             "source": 1745,
#             "target": 848,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- ACETOVANILLONE_c"
#         },
#         {
#             "source": 1745,
#             "target": 266,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- CO_A_c"
#         },
#         {
#             "source": 1745,
#             "target": 257,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- PROTON_c"
#         },
#         {
#             "source": 1745,
#             "target": 849,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- aACETOVANILLONE_c"
#         },
#         {
#             "source": 1745,
#             "target": 678,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- NADH_c"
#         },
#         {
#             "source": 1745,
#             "target": 381,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_SYNTHASE_c -- CARBON_DIOXIDE_c"
#         },
#         {
#             "source": 848,
#             "target": 1746,
#             "interaction": "in",
#             "reversible": false,
#             "id": "ACETOVANILLONE_c -- ACETOVANILLONE_HYDROXYLASE_c"
#         },
#         {
#             "source": 257,
#             "target": 1746,
#             "interaction": "in",
#             "reversible": false,
#             "id": "PROTON_c -- ACETOVANILLONE_HYDROXYLASE_c"
#         },
#         {
#             "source": 489,
#             "target": 1746,
#             "interaction": "in",
#             "reversible": false,
#             "id": "OXYGEN_MOLECULE_c -- ACETOVANILLONE_HYDROXYLASE_c"
#         },
#         {
#             "source": 22,
#             "target": 1746,
#             "interaction": "in",
#             "reversible": false,
#             "id": "NADPH_c -- ACETOVANILLONE_HYDROXYLASE_c"
#         },
#         {
#             "source": 849,
#             "target": 1746,
#             "interaction": "in",
#             "reversible": false,
#             "id": "aACETOVANILLONE_c -- ACETOVANILLONE_HYDROXYLASE_c"
#         },
#         {
#             "source": 1746,
#             "target": 484,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_HYDROXYLASE_c -- NADP_c"
#         },
#         {
#             "source": 1746,
#             "target": 199,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_HYDROXYLASE_c -- WATER_c"
#         },
#         {
#             "source": 1746,
#             "target": 850,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_HYDROXYLASE_c -- 5_HYDROXY_ACETOVANILLONE_c"
#         },
#         {
#             "source": 1746,
#             "target": 851,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOVANILLONE_HYDROXYLASE_c -- a5_HYDROXY_ACETOVANILLONE_c"
#         },
#         {
#             "source": 851,
#             "target": 1747,
#             "interaction": "in",
#             "reversible": false,
#             "id": "a5_HYDROXY_ACETOVANILLONE_c -- ACETOSYRINGONE_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 328,
#             "target": 1747,
#             "interaction": "in",
#             "reversible": false,
#             "id": "S_ADENOSYLMETHIONINE_c -- ACETOSYRINGONE_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 850,
#             "target": 1747,
#             "interaction": "in",
#             "reversible": false,
#             "id": "5_HYDROXY_ACETOVANILLONE_c -- ACETOSYRINGONE_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 1747,
#             "target": 257,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOSYRINGONE_BIOSYNTHESIS_c -- PROTON_c"
#         },
#         {
#             "source": 1747,
#             "target": 348,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOSYRINGONE_BIOSYNTHESIS_c -- ADENOSYL_HOMO_CYS_c"
#         },
#         {
#             "source": 1747,
#             "target": 853,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOSYRINGONE_BIOSYNTHESIS_c -- aACETOSYRINGONE_c"
#         },
#         {
#             "source": 1747,
#             "target": 852,
#             "interaction": "out",
#             "reversible": false,
#             "id": "ACETOSYRINGONE_BIOSYNTHESIS_c -- ACETOSYRINGONE_c"
#         },
#         {
#             "source": 257,
#             "target": 1748,
#             "interaction": "in",
#             "reversible": false,
#             "id": "PROTON_c -- RXN_1121_c"
#         },
#         {
#             "source": 22,
#             "target": 1748,
#             "interaction": "in",
#             "reversible": false,
#             "id": "NADPH_c -- RXN_1121_c"
#         },
#         {
#             "source": 842,
#             "target": 1748,
#             "interaction": "in",
#             "reversible": false,
#             "id": "FERULIC_ACID_c -- RXN_1121_c"
#         },
#         {
#             "source": 489,
#             "target": 1748,
#             "interaction": "in",
#             "reversible": false,
#             "id": "OXYGEN_MOLECULE_c -- RXN_1121_c"
#         },
#         {
#             "source": 1748,
#             "target": 484,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_1121_c -- NADP_c"
#         },
#         {
#             "source": 1748,
#             "target": 199,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_1121_c -- WATER_c"
#         },
#         {
#             "source": 1748,
#             "target": 854,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_1121_c -- 5_HYDROXY_FERULIC_ACID_c"
#         },
#         {
#             "source": 854,
#             "target": 1749,
#             "interaction": "in",
#             "reversible": false,
#             "id": "5_HYDROXY_FERULIC_ACID_c -- RXN_3422_c"
#         },
#         {
#             "source": 328,
#             "target": 1749,
#             "interaction": "in",
#             "reversible": false,
#             "id": "S_ADENOSYLMETHIONINE_c -- RXN_3422_c"
#         },
#         {
#             "source": 1749,
#             "target": 855,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_3422_c -- SINAPATE_c"
#         },
#         {
#             "source": 1749,
#             "target": 348,
#             "interaction": "out",
#             "reversible": false,
#             "id": "RXN_3422_c -- ADENOSYL_HOMO_CYS_c"
#         },
#         {
#             "source": 855,
#             "target": 1750,
#             "interaction": "in",
#             "reversible": false,
#             "id": "SINAPATE_c -- SYRINGALDEHYDE_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 199,
#             "target": 1750,
#             "interaction": "in",
#             "reversible": false,
#             "id": "WATER_c -- SYRINGALDEHYDE_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 1750,
#             "target": 257,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGALDEHYDE_BIOSYNTHESIS_c -- PROTON_c"
#         },
#         {
#             "source": 1750,
#             "target": 857,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGALDEHYDE_BIOSYNTHESIS_c -- aSYRINGALDEHYDE_c"
#         },
#         {
#             "source": 1750,
#             "target": 856,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGALDEHYDE_BIOSYNTHESIS_c -- SYRINGALDEHYDE_c"
#         },
#         {
#             "source": 1750,
#             "target": 267,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGALDEHYDE_BIOSYNTHESIS_c -- ACET_c"
#         },
#         {
#             "source": 199,
#             "target": 1751,
#             "interaction": "in",
#             "reversible": false,
#             "id": "WATER_c -- SYRINGICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 857,
#             "target": 1751,
#             "interaction": "in",
#             "reversible": false,
#             "id": "aSYRINGALDEHYDE_c -- SYRINGICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 856,
#             "target": 1751,
#             "interaction": "in",
#             "reversible": false,
#             "id": "SYRINGALDEHYDE_c -- SYRINGICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 176,
#             "target": 1751,
#             "interaction": "in",
#             "reversible": false,
#             "id": "NAD_c -- SYRINGICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 1751,
#             "target": 257,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGICACID_BIOSYNTHESIS_c -- PROTON_c"
#         },
#         {
#             "source": 1751,
#             "target": 858,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGICACID_BIOSYNTHESIS_c -- SYRINGIC_ACID_c"
#         },
#         {
#             "source": 1751,
#             "target": 678,
#             "interaction": "out",
#             "reversible": false,
#             "id": "SYRINGICACID_BIOSYNTHESIS_c -- NADH_c"
#         },
#         {
#             "source": 835,
#             "target": 1752,
#             "interaction": "in",
#             "reversible": false,
#             "id": "VANILLIN_c -- VANILLICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 176,
#             "target": 1752,
#             "interaction": "in",
#             "reversible": false,
#             "id": "NAD_c -- VANILLICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 199,
#             "target": 1752,
#             "interaction": "in",
#             "reversible": false,
#             "id": "WATER_c -- VANILLICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 836,
#             "target": 1752,
#             "interaction": "in",
#             "reversible": false,
#             "id": "aVANILLIN_c -- VANILLICACID_BIOSYNTHESIS_c"
#         },
#         {
#             "source": 1752,
#             "target": 257,
#             "interaction": "out",
#             "reversible": false,
#             "id": "VANILLICACID_BIOSYNTHESIS_c -- PROTON_c"
#         },
#         {
#             "source": 1752,
#             "target": 859,
#             "interaction": "out",
#             "reversible": false,
#             "id": "VANILLICACID_BIOSYNTHESIS_c -- VANILLIC_ACID_c"
#         },
#         {
#             "source": 1752,
#             "target": 678,
#             "interaction": "out",
#             "reversible": false,
#             "id": "VANILLICACID_BIOSYNTHESIS_c -- NADH_c"
#         }
#     ]
# }

# %%
import os
from model_duplication.visualization import converter

converter.cobra2metexplore_file(textbook, "./textbook.json")

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'Constraints.ipynb',
#  'LinkageAndPhases.ipynb',
#  'Visualization',
#  'converter.ipynb',
#  'textbook.json']

# %% [markdown]
# Now we create the tsv file, which contains the flux values and can later be read by MetExploreViz.
#
# First we set the solver that we want to use.
#
# We create a solution for the problem and translate it into a file that can be read by MetExploreViz.

# %%
textbook.solver = "glpk"
solution = textbook.optimize()

converter.cobra2metexplore_flux_file(solution, "./textbook_flux.csv")

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'Constraints.ipynb',
#  'LinkageAndPhases.ipynb',
#  'Visualization',
#  'converter.ipynb',
#  'textbook.json',
#  'textbook_flux.csv']
